# %%
import pandas as pd
from citipy import citipy
import numpy as np
import requests
from config import weather_api_key

# %%
lats=np.random.uniform(-180,180,2000)
lngs=np.random.uniform(-180,180,2000)

# %%
coordinates=zip(lats,lngs)

# %%
coordinates=list(coordinates)

# %%
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 462

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_decription = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_decription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# 1 | rizhao
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | mayumba
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | namatanai
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | carupano
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | ulladulla
# Processing Record 26 of Set 1 | mehamn
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | mpika
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 1 | cururupu
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 1 | seddon
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | bira
# Processing Record 42 of Set 1 | karatau
# Processing Record 43 of Set 1 | qui nhon
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | taltal
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | okhotsk
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | dudinka
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | saint anthony
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | kaeo
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | manono
# Processing Record 11 of Set 2 | camacha
# Processing Record 12 of Set 2 | lata
# Processing Record 13 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 2 | gamboma
# Processing Record 15 of Set 2 | kedrovyy
# Processing Record 16 of Set 2 | terrace
# Processing Record 17 of Set 2 | guadix
# Processing Record 18 of Set 2 | pulandian
# Processing Record 19 of Set 2 | ahipara
# Processing Record 20 of Set 2 | acapulco
# Processing Record 21 of Set 2 | dhidhdhoo
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | hima
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | broken hill
# Processing Record 32 of Set 2 | klyuchi
# Processing Record 33 of Set 2 | manokwari
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | maldonado
# Processing Record 36 of Set 2 | sakakah
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | prince rupert
# Processing Record 39 of Set 2 | mmathubudukwane
# Processing Record 40 of Set 2 | nanakuli
# Processing Record 41 of Set 2 | ojinaga
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | carutapera
# Processing Record 47 of Set 2 | birin
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | quatre cocos
# Processing Record 1 of Set 3 | ayan
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | atasu
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | saint-pierre
# Processing Record 8 of Set 3 | quimperle
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | benavente
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | labuhan
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | solton
# Processing Record 20 of Set 3 | deogarh
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | atocha
# Processing Record 25 of Set 3 | shimoda
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | leninskoye
# Processing Record 29 of Set 3 | spencer
# Processing Record 30 of Set 3 | ancud
# Processing Record 31 of Set 3 | viradouro
# Processing Record 32 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 3 | comodoro rivadavia
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | margate
# Processing Record 36 of Set 3 | leshukonskoye
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | budingen
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | baculin
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | preobrazheniye
# Processing Record 45 of Set 3 | halifax
# Processing Record 46 of Set 3 | mbandaka
# Processing Record 47 of Set 3 | matay
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | lavrentiya
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | bani
# Processing Record 3 of Set 4 | mlonggo
# Processing Record 4 of Set 4 | belyy yar
# Processing Record 5 of Set 4 | srednekolymsk
# Processing Record 6 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 4 | duz
# City not found. Skipping...
# Processing Record 8 of Set 4 | henties bay
# Processing Record 9 of Set 4 | beloha
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | salym
# Processing Record 12 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | lephepe
# City not found. Skipping...
# Processing Record 16 of Set 4 | aparecida do taboado
# Processing Record 17 of Set 4 | barranquilla
# Processing Record 18 of Set 4 | paamiut
# Processing Record 19 of Set 4 | vaitape
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | bonavista
# Processing Record 23 of Set 4 | diu
# Processing Record 24 of Set 4 | wageningen
# Processing Record 25 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 4 | qianan
# Processing Record 27 of Set 4 | salalah
# Processing Record 28 of Set 4 | tabuk
# Processing Record 29 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 4 | dargaville
# Processing Record 31 of Set 4 | salinopolis
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | lima
# Processing Record 35 of Set 4 | ulaangom
# Processing Record 36 of Set 4 | guaratinga
# Processing Record 37 of Set 4 | along
# Processing Record 38 of Set 4 | porto novo
# Processing Record 39 of Set 4 | egvekinot
# Processing Record 40 of Set 4 | nagornskiy
# Processing Record 41 of Set 4 | saint-georges
# Processing Record 42 of Set 4 | bathsheba
# Processing Record 43 of Set 4 | nhulunbuy
# Processing Record 44 of Set 4 | the valley
# Processing Record 45 of Set 4 | clifton
# Processing Record 46 of Set 4 | ilo
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | grand gaube
# Processing Record 49 of Set 4 | tuatapere
# Processing Record 50 of Set 4 | haines junction
# Processing Record 1 of Set 5 | kanina
# Processing Record 2 of Set 5 | denpasar
# Processing Record 3 of Set 5 | lunca corbului
# Processing Record 4 of Set 5 | madison heights
# Processing Record 5 of Set 5 | lasa
# Processing Record 6 of Set 5 | iqaluit
# Processing Record 7 of Set 5 | bismil
# Processing Record 8 of Set 5 | adrar
# Processing Record 9 of Set 5 | voi
# Processing Record 10 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 11 of Set 5 | caravelas
# Processing Record 12 of Set 5 | glendive
# Processing Record 13 of Set 5 | pahrump
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | sabya
# Processing Record 16 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 5 | murgab
# Processing Record 21 of Set 5 | turiacu
# Processing Record 22 of Set 5 | nassau
# Processing Record 23 of Set 5 | buin
# Processing Record 24 of Set 5 | salacgriva
# Processing Record 25 of Set 5 | abong mbang
# Processing Record 26 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 5 | mercedes
# Processing Record 28 of Set 5 | port pirie
# Processing Record 29 of Set 5 | hammerfest
# Processing Record 30 of Set 5 | yulara
# Processing Record 31 of Set 5 | juxian
# City not found. Skipping...
# Processing Record 32 of Set 5 | valdivia
# Processing Record 33 of Set 5 | provideniya
# Processing Record 34 of Set 5 | san policarpo
# Processing Record 35 of Set 5 | roma
# Processing Record 36 of Set 5 | sur
# Processing Record 37 of Set 5 | vangaindrano
# Processing Record 38 of Set 5 | olafsvik
# Processing Record 39 of Set 5 | banposh
# Processing Record 40 of Set 5 | lyuban
# Processing Record 41 of Set 5 | kollam
# Processing Record 42 of Set 5 | ballina
# Processing Record 43 of Set 5 | pandan
# Processing Record 44 of Set 5 | havre-saint-pierre
# Processing Record 45 of Set 5 | yumen
# Processing Record 46 of Set 5 | mount isa
# Processing Record 47 of Set 5 | kaitangata
# Processing Record 48 of Set 5 | verkhnevilyuysk
# Processing Record 49 of Set 5 | emba
# Processing Record 50 of Set 5 | vostok
# Processing Record 1 of Set 6 | belem de sao francisco
# Processing Record 2 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 6 | slave lake
# Processing Record 4 of Set 6 | havoysund
# Processing Record 5 of Set 6 | chuy
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | basco
# Processing Record 8 of Set 6 | simao
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | vieques
# Processing Record 11 of Set 6 | lorengau
# Processing Record 12 of Set 6 | dawei
# Processing Record 13 of Set 6 | fushun
# Processing Record 14 of Set 6 | kupang
# Processing Record 15 of Set 6 | castellarano
# Processing Record 16 of Set 6 | sibolga
# Processing Record 17 of Set 6 | goderich
# Processing Record 18 of Set 6 | ocampo
# Processing Record 19 of Set 6 | shikohabad
# Processing Record 20 of Set 6 | karasjok
# Processing Record 21 of Set 6 | tefe
# Processing Record 22 of Set 6 | ahuimanu
# Processing Record 23 of Set 6 | half moon bay
# Processing Record 24 of Set 6 | brae
# Processing Record 25 of Set 6 | hanmer springs
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | roros
# Processing Record 28 of Set 6 | kearney
# Processing Record 29 of Set 6 | dubbo
# Processing Record 30 of Set 6 | port moresby
# Processing Record 31 of Set 6 | saint-leu
# Processing Record 32 of Set 6 | skibbereen
# Processing Record 33 of Set 6 | samarai
# Processing Record 34 of Set 6 | tadine
# Processing Record 35 of Set 6 | payson
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | sioux lookout
# Processing Record 38 of Set 6 | heyang
# Processing Record 39 of Set 6 | asfi
# Processing Record 40 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 6 | bud
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | inta
# Processing Record 45 of Set 6 | huntingdon
# Processing Record 46 of Set 6 | berdigestyakh
# Processing Record 47 of Set 6 | cambridge
# Processing Record 48 of Set 6 | visnes
# Processing Record 49 of Set 6 | zhigansk
# Processing Record 50 of Set 6 | zeya
# Processing Record 1 of Set 7 | hami
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | ferrandina
# Processing Record 4 of Set 7 | vidim
# Processing Record 5 of Set 7 | igbo ora
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | dayong
# Processing Record 8 of Set 7 | zhigalovo
# Processing Record 9 of Set 7 | san patricio
# Processing Record 10 of Set 7 | airai
# Processing Record 11 of Set 7 | nanortalik
# Processing Record 12 of Set 7 | hay river
# Processing Record 13 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | sar-e pul
# Processing Record 16 of Set 7 | liberal
# Processing Record 17 of Set 7 | os
# City not found. Skipping...
# Processing Record 18 of Set 7 | gazanjyk
# Processing Record 19 of Set 7 | viedma
# Processing Record 20 of Set 7 | borujan
# City not found. Skipping...
# Processing Record 21 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 7 | terra santa
# Processing Record 24 of Set 7 | ewa beach
# Processing Record 25 of Set 7 | treinta y tres
# Processing Record 26 of Set 7 | tianpeng
# Processing Record 27 of Set 7 | balkanabat
# Processing Record 28 of Set 7 | toulepleu
# City not found. Skipping...
# Processing Record 29 of Set 7 | mogochin
# City not found. Skipping...
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | fairbanks
# Processing Record 32 of Set 7 | igrim
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | kandava
# Processing Record 35 of Set 7 | lincoln
# Processing Record 36 of Set 7 | makakilo city
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | lagoa
# Processing Record 39 of Set 7 | uttaradit
# Processing Record 40 of Set 7 | pella
# Processing Record 41 of Set 7 | voh
# Processing Record 42 of Set 7 | srandakan
# Processing Record 43 of Set 7 | shache
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | lano
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | yerbogachen
# Processing Record 49 of Set 7 | santa cruz
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | kurduvadi
# Processing Record 2 of Set 8 | maceio
# Processing Record 3 of Set 8 | east london
# Processing Record 4 of Set 8 | rio gallegos
# Processing Record 5 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 8 | mazatlan
# Processing Record 7 of Set 8 | belle fourche
# Processing Record 8 of Set 8 | soverato
# Processing Record 9 of Set 8 | deputatskiy
# Processing Record 10 of Set 8 | gamba
# Processing Record 11 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 8 | new kensington
# Processing Record 13 of Set 8 | puerto rondon
# Processing Record 14 of Set 8 | aykhal
# Processing Record 15 of Set 8 | la ronge
# Processing Record 16 of Set 8 | tupiza
# Processing Record 17 of Set 8 | kununurra
# Processing Record 18 of Set 8 | ixtapa
# Processing Record 19 of Set 8 | sarankhola
# Processing Record 20 of Set 8 | seoul
# Processing Record 21 of Set 8 | volchikha
# Processing Record 22 of Set 8 | kupiskis
# Processing Record 23 of Set 8 | launceston
# Processing Record 24 of Set 8 | santa maria
# Processing Record 25 of Set 8 | mayor pablo lagerenza
# Processing Record 26 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 27 of Set 8 | royan
# Processing Record 28 of Set 8 | neuquen
# Processing Record 29 of Set 8 | pangody
# Processing Record 30 of Set 8 | gat
# Processing Record 31 of Set 8 | kangaatsiaq
# Processing Record 32 of Set 8 | pringsewu
# Processing Record 33 of Set 8 | decatur
# Processing Record 34 of Set 8 | anloga
# Processing Record 35 of Set 8 | bowen
# Processing Record 36 of Set 8 | xining
# Processing Record 37 of Set 8 | vestmannaeyjar
# Processing Record 38 of Set 8 | calvia
# Processing Record 39 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 8 | cap malheureux
# Processing Record 41 of Set 8 | houma
# Processing Record 42 of Set 8 | kang
# Processing Record 43 of Set 8 | coquimbo
# Processing Record 44 of Set 8 | berlevag
# Processing Record 45 of Set 8 | sharya
# Processing Record 46 of Set 8 | los llanos de aridane
# Processing Record 47 of Set 8 | wukari
# Processing Record 48 of Set 8 | berlin
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | tacuarembo
# Processing Record 1 of Set 9 | kathu
# Processing Record 2 of Set 9 | nurota
# Processing Record 3 of Set 9 | bengkulu
# Processing Record 4 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 9 | kiunga
# Processing Record 6 of Set 9 | shumskiy
# Processing Record 7 of Set 9 | inhambane
# Processing Record 8 of Set 9 | mushie
# Processing Record 9 of Set 9 | whangamata
# Processing Record 10 of Set 9 | bekhtery
# Processing Record 11 of Set 9 | puerto ayacucho
# Processing Record 12 of Set 9 | olinda
# Processing Record 13 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 9 | roebourne
# Processing Record 15 of Set 9 | mankono
# Processing Record 16 of Set 9 | santa cruz del sur
# Processing Record 17 of Set 9 | montepuez
# Processing Record 18 of Set 9 | pangai
# Processing Record 19 of Set 9 | fortuna
# Processing Record 20 of Set 9 | sol-iletsk
# Processing Record 21 of Set 9 | tazovskiy
# Processing Record 22 of Set 9 | junqueiropolis
# Processing Record 23 of Set 9 | ciudad bolivar
# Processing Record 24 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 9 | cockburn town
# Processing Record 27 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 9 | kholm
# Processing Record 29 of Set 9 | pangnirtung
# Processing Record 30 of Set 9 | darnah
# Processing Record 31 of Set 9 | tecoanapa
# Processing Record 32 of Set 9 | san vicente
# Processing Record 33 of Set 9 | biak
# Processing Record 34 of Set 9 | praia
# Processing Record 35 of Set 9 | volkach
# Processing Record 36 of Set 9 | grindavik
# Processing Record 37 of Set 9 | lefka
# Processing Record 38 of Set 9 | nome
# Processing Record 39 of Set 9 | taikang
# Processing Record 40 of Set 9 | limon
# Processing Record 41 of Set 9 | atambua
# Processing Record 42 of Set 9 | gouyave
# Processing Record 43 of Set 9 | assiniboia
# Processing Record 44 of Set 9 | muros
# Processing Record 45 of Set 9 | port-gentil
# Processing Record 46 of Set 9 | isakly
# Processing Record 47 of Set 9 | gizo
# Processing Record 48 of Set 9 | constitucion
# Processing Record 49 of Set 9 | burgeo
# Processing Record 50 of Set 9 | verkhoyansk
# Processing Record 1 of Set 10 | tibati
# Processing Record 2 of Set 10 | sompeta
# Processing Record 3 of Set 10 | bure
# Processing Record 4 of Set 10 | suleja
# Processing Record 5 of Set 10 | palestine
# Processing Record 6 of Set 10 | avera
# Processing Record 7 of Set 10 | caxito
# Processing Record 8 of Set 10 | cody
# Processing Record 9 of Set 10 | birao
# Processing Record 10 of Set 10 | bridlington
# Processing Record 11 of Set 10 | san isidro
# Processing Record 12 of Set 10 | sueyoshi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tasiilaq      GL  65.6145  -37.6368     24.80        58          75
# 1      Butaritari      KI   3.0707  172.7902     81.21        82          83
# 2  Severo-Kurilsk      RU  50.6789  156.1250     11.59        82          42
# 3     Tuktoyaktuk      CA  69.4541 -133.0374    -25.60        75          75
# 4     Port Alfred      ZA -33.5906   26.8910     70.00        94          94
# 5          Barrow      US  71.2906 -156.7887     -2.20        78          90
# 6          Rizhao      CN  35.4275  119.4553     40.69        74           0
# 7          Dikson      RU  73.5069   80.5464    -33.79        83           4
# 8      Nikolskoye      RU  59.7035   30.7861     12.00        78          75
# 9         Qaanaaq      GL  77.4840  -69.3632     -8.28        75         100
#
#    Wind Speed Current Description
# 0        3.44       broken clouds
# 1       16.71          light rain
# 2        5.97    scattered clouds
# 3       14.97                snow
# 4       16.22     overcast clouds
# 5       11.50                snow
# 6        9.66           clear sky
# 7       10.13           clear sky
# 8       11.18          light snow
# 9        8.39     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
